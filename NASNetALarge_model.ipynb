# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch torchvision timm matplotlib seaborn

# %%
import torch
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, random_split

data_dir = '/content/drive/MyDrive/UCMerced_LandUse/UCMerced_LandUse/Images_converted'
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

dataset = ImageFolder(root=data_dir, transform=transform)

train_size = int(0.7 * len(dataset))
val_size = int(0.15 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_nasnet = timm.create_model('nasnetalarge', pretrained=True)
model_nasnet.num_classes = len(dataset.classes)
model_nasnet.last_linear = nn.Linear(model_nasnet.last_linear.in_features, model_nasnet.num_classes)
model_nasnet = model_nasnet.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_nasnet.parameters(), lr=3e-5)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

# %%
epochs = 25
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []

for epoch in range(epochs):
    model_nasnet.train()
    running_loss, correct, total = 0.0, 0, 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model_nasnet(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    train_losses.append(running_loss / len(train_loader))
    train_accuracies.append(100 * correct / total)
    scheduler.step()

    model_nasnet.eval()
    val_loss, correct, total = 0.0, 0, 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_nasnet(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total += labels.size(0)
            correct += (preds == labels).sum().item()
    val_losses.append(val_loss / len(val_loader))
    val_accuracies.append(100 * correct / total)
    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_losses[-1]:.4f}, Train Acc: {train_accuracies[-1]:.2f}%, "
          f"Val Loss: {val_losses[-1]:.4f}, Val Acc: {val_accuracies[-1]:.2f}%")
# Out:
# Epoch 1/25, Train Loss: 2.6699, Train Acc: 39.25%, Val Loss: 2.0677, Val Acc: 71.11%
# Epoch 2/25, Train Loss: 1.3772, Train Acc: 84.69%, Val Loss: 0.8415, Val Acc: 91.75%
# Epoch 3/25, Train Loss: 0.4552, Train Acc: 96.05%, Val Loss: 0.2638, Val Acc: 97.46%
# Epoch 4/25, Train Loss: 0.1201, Train Acc: 99.05%, Val Loss: 0.1080, Val Acc: 98.10%
# Epoch 5/25, Train Loss: 0.0416, Train Acc: 99.80%, Val Loss: 0.0762, Val Acc: 98.10%
# Epoch 6/25, Train Loss: 0.0237, Train Acc: 99.93%, Val Loss: 0.0614, Val Acc: 98.41%
# Epoch 7/25, Train Loss: 0.0255, Train Acc: 99.73%, Val Loss: 0.0514, Val Acc: 98.73%
# Epoch 8/25, Train Loss: 0.0174, Train Acc: 99.86%, Val Loss: 0.0518, Val Acc: 98.41%
# Epoch 9/25, Train Loss: 0.0177, Train Acc: 99.80%, Val Loss: 0.0534, Val Acc: 98.73%
# Epoch 10/25, Train Loss: 0.0139, Train Acc: 99.93%, Val Loss: 0.0455, Val Acc: 98.73%
# Epoch 11/25, Train Loss: 0.0107, Train Acc: 100.00%, Val Loss: 0.0489, Val Acc: 98.73%
# ...

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

model_nasnet.eval()
all_preds, all_labels = [], []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model_nasnet(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

test_accuracy = accuracy_score(all_labels, all_preds)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

conf_matrix = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', xticklabels=dataset.classes, yticklabels=dataset.classes)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - NASNetALarge')
plt.show()

print("Classification Report:")
print(classification_report(all_labels, all_preds, target_names=dataset.classes))
# Out:
# Test Accuracy: 97.14%
# Classification Report:
#                    precision    recall  f1-score   support
#
#      agricultural       1.00      1.00      1.00        19
#          airplane       1.00      1.00      1.00        24
#   baseballdiamond       1.00      1.00      1.00        15
#             beach       1.00      1.00      1.00        13
#         buildings       0.93      0.93      0.93        15
#         chaparral       1.00      1.00      1.00        22
#  denseresidential       0.94      0.83      0.88        18
#            forest       0.94      1.00      0.97        16
#           freeway       1.00      1.00      1.00        19
#        golfcourse       0.93      0.93      0.93        14
#            harbor       1.00      1.00      1.00        11
#      intersection       0.92      1.00      0.96        11
# mediumresidential       0.87      0.93      0.90        14
#    mobilehomepark       0.94      1.00      0.97        15
# ...

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Curve')
plt.legend()

plt.tight_layout()
plt.show()
